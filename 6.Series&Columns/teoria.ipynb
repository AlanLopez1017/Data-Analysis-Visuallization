# %%
import pandas as pd
houses = pd.read_csv("../DataAnalysis/data/kc_house_data.csv")
titanic = pd.read_csv("../DataAnalysis/data/titanic.csv")
netflix = pd.read_csv("../DataAnalysis/data/netflix_titles.csv", sep="|", index_col=0)

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
type(titanic.name) # series usando punto y []
# Out:
# pandas.core.series.Series

# %%
titanic["name"]
# Out:
# pandas.core.series.Series

# %%
titanic["home.dest"] # con punto no funciona en estos casos o si hubieran espacios
# Out:
# 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
#                      ...
# 1304                                  ?
# 1305                                  ?
# 1306                                  ?
# 1307                                  ?
# 1308                                  ?
# Name: home.dest, Length: 1309, dtype: object

# %%
mystery_col = "price"
houses[mystery_col]
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %% [markdown]
# # Series

# %%
names = titanic.name
type(names)
# Un serie es un one-dimensional ndarray with axis labels
# Out:
# pandas.core.series.Series

# %%
houses.mean() # los labels son los nombres de cada columna

# %%
houses.sum(numeric_only=True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.865249e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
houses.price.sum() # .min(), .max()
# Out:
# 11672925008.0

# %%
names.shape
# Out:
# (1309,)

# %%
names.values
# Out:
# array(['Allen, Miss. Elisabeth Walton', 'Allison, Master. Hudson Trevor',
#        'Allison, Miss. Helen Loraine', ..., 'Zakarian, Mr. Mapriededer',
#        'Zakarian, Mr. Ortin', 'Zimmerman, Mr. Leo'], dtype=object)

# %%
names.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
houses.min(numeric_only=True).index
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## Importantes métodos de las Series
# * head()
# * tail()
# * describe()
# * unique()
# * nunique()
# * nlargest()
# * nsmallest()
# * value_counts()
# * plot()

# %%
names
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic.age.head(10)
# Out:
# 0        29
# 1    0.9167
# 2         2
# 3        30
# 4        25
# 5        48
# 6        63
# 7        39
# 8        53
# 9        71
# Name: age, dtype: object

# %%
netflix.title.tail(13)
# Out:
# 8794                اشتباك
# 8795       Yu-Gi-Oh! Arc-V
# 8796            Yunus Emre
# 8797             Zak Storm
# 8798              Zed Plus
# 8799                 Zenda
# 8800    Zindagi Gulzar Hai
# 8801               Zinzana
# 8802                Zodiac
# 8803           Zombie Dumb
# 8804            Zombieland
# 8805                  Zoom
# 8806                Zubaan
# Name: title, dtype: object

# %%
#describe
houses.price.describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
netflix["rating"].describe()
# Out:
# count      8803
# unique       17
# top       TV-MA
# freq       3207
# Name: rating, dtype: object

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix["release_year"].describe()
# Out:
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %% [markdown]
# # Unique & nunique

# %%
houses["bedrooms"].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
houses["bedrooms"].nunique()
# Out:
# 13

# %%
netflix.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix.rating.nunique(dropna=False) # contará hasta lo na con dropna=False
# Out:
# 17

# %%
houses.zipcode.nunique()
# Out:
# 70

# %% [markdown]
# # nlargest & nsmallest

# %%
houses.price.nlargest()
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# Name: price, dtype: float64

# %%
houses.price.nsmallest(10)
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# 2141     82500.0
# 18468    83000.0
# 3767     84000.0
# 10253    85000.0
# 16714    85000.0
# Name: price, dtype: float64

# %%
# es más rápido que .sort_values(ascending=False).head(n) para pequeños n relativos al tamaño del objeto Series

# %%
titanic.pclass.nlargest(5, keep='all') # con datos duplicados
# Out:
# 600    3
# 601    3
# 602    3
# 603    3
# 604    3
# Name: pclass, dtype: int64

# %%
houses.nlargest(10, ["price"])
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses.nlargest(10, ["bedrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses.nlargest(10, ["bedrooms", "bathrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %% [markdown]
# # Selecting multiple columns

# %%
netflix[["title", "director"]]
# Out:
#                       title         director
# 0      Dick Johnson Is Dead  Kirsten Johnson
# 1             Blood & Water              NaN
# 2                 Ganglands  Julien Leclercq
# 3     Jailbirds New Orleans              NaN
# 4              Kota Factory              NaN
# ...                     ...              ...
# 8802                 Zodiac    David Fincher
# 8803            Zombie Dumb              NaN
# 8804             Zombieland  Ruben Fleischer
# 8805                   Zoom     Peter Hewitt
# 8806                 Zubaan      Mozez Singh
#
# [8807 rows x 2 columns]

# %%
houses[["price", "bedrooms", "bathrooms"]].describe()
# Out:
#               price      bedrooms     bathrooms
# count  2.161300e+04  21613.000000  21613.000000
# mean   5.400881e+05      3.370842      2.114757
# std    3.671272e+05      0.930062      0.770163
# min    7.500000e+04      0.000000      0.000000
# 25%    3.219500e+05      3.000000      1.750000
# 50%    4.500000e+05      3.000000      2.250000
# 75%    6.450000e+05      4.000000      2.500000
# max    7.700000e+06     33.000000      8.000000

# %%
cols = ["price", "zipcode", "sqft_lot"]
houses[cols]
# Out:
#           price  zipcode  sqft_lot
# 0      221900.0    98178      5650
# 1      538000.0    98125      7242
# 2      180000.0    98028     10000
# 3      604000.0    98136      5000
# 4      510000.0    98074      8080
# ...         ...      ...       ...
# 21608  360000.0    98103      1131
# 21609  400000.0    98146      5813
# 21610  402101.0    98144      1350
# 21611  400000.0    98027      2388
# 21612  325000.0    98144      1076
#
# [21613 rows x 3 columns]
